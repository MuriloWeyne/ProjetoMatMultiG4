# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
### Plotando Curva
ax = plt.axes()

# Data for a three-dimensional line
zdata = np.linspace(0, 2*np.pi, 1_000, endpoint=False)
xdata = (21/2)*np.cos(zdata) - (21/4)*np.cos(6*zdata)
ydata = (21/2)*np.sin(zdata) - (21/4)*np.sin(6*zdata)

ax.grid()
ax.plot(xdata, ydata, 'gray');
